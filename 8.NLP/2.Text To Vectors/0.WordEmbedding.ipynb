# %% [markdown]
# ## Word Embedding :
# In natural language processing (NLP), word embedding is a term used for the representation of words for text analysis, typically in the form of a real-valued vector that encodes the meaning of the word such that the words that are closer in the vector space are expected to be similar in meaning.
#
# all these techniques like one hot encodding , bag of words and tf-idf comes under word embedding only , they all comes under count or frequency category of word embedding . these techniques do embed words to vectors but they do not have any semantic meanings to them .
#
#
# more better category of word embedding is Deep learning trained model known as word2vec (word to vector) which solves all the disadvanges of above techniques .
