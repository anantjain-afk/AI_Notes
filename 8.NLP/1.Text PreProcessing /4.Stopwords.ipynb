# %% [markdown]
#  Natural language processing tasks often involve filtering out commonly occurring words that provide no or very little semantic value to text analysis. These words are known as stopwords

# %%
import nltk 
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/anantjain/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## When to Remove Stopwords
# The decision to remove stopwords depends heavily on the specific NLP task at hand:
#
# ## Tasks that benefit from stopword removal:
# Text classification and sentiment analysis
# Information retrieval and search engines.
# Topic modelling and clustering.
# Keyword extraction
# ## Tasks that require preserving stopwords:
# Machine translation (maintains grammatical structure),
# Text summarization (preserves sentence coherence),
# Question-answering systems (syntactic relationships matter),
# Grammar checking and parsing

# %%
stopwords = nltk.corpus.stopwords
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
from nltk import PorterStemmer ;
from nltk import WordNetLemmatizer
from nltk import SnowballStemmer
from nltk.corpus import wordnet
nltk.download("wordnet")
porter = PorterStemmer() ;
snowball = SnowballStemmer('english') ;
lemmatizer = WordNetLemmatizer()


para= '''"'"I have three visions for India. In 3000 years of our history, people from all over the world have come and invaded us, captured our lands, conquered our minds.
From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the Brit the French, the Dutch, all of them came and looted us, took over what was ours.
Yet we have not done
this to any other nation. We have not conquered anyone.
We have not grabbed their land, their culture, their history and tried to enforce our way of life on them.
Why? Because we respect the freedom of others. That is why my first vision is that of freedom. I believer that India got its first vision of this in 1857, when we started the War of Independence. It is this freedom that we must protect and nurture and build on. If we are not free, no one will res
My second vision
for India's development. For fifty years we have been a
It is time we
ourselves
as a developed
nation. We are among the top
in terms of GDP. We have a 10 percent growth rate in most areas. Our Our achievements are being globally recognised today. Yet we lack the
see ourselves
as a developed nation, self-reliant and self-assured.
I have a third vision. India must stand up to the world. Because I b stands up to the world, no one will respect us. Only strength respec strong not only as a military power but also as an economic power. Bd
My good fortune was to have worked with three great minds. Dr. Vikram space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, '''
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/anantjain/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# first apply tokenization 
sentences = nltk.sent_tokenize(para)
print("before" , sentences)
# now apply stopword removal and stemming
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    # remove stopwords and stem the words
    words = [lemmatizer.lemmatize(word, pos='v') for word in words if word.lower() not in set(stopwords.words('english'))]
    # convert list of words back to sentence.
    sentences[i] = ' '.join(words)
print("after" , sentences)
# Out:
# before ['"\'"I have three visions for India.', 'In 3000 years of our history, people from all over the world have come and invaded us, captured our lands, conquered our minds.', 'From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the Brit the French, the Dutch, all of them came and looted us, took over what was ours.', 'Yet we have not done\nthis to any other nation.', 'We have not conquered anyone.', 'We have not grabbed their land, their culture, their history and tried to enforce our way of life on them.', 'Why?', 'Because we respect the freedom of others.', 'That is why my first vision is that of freedom.', 'I believer that India got its first vision of this in 1857, when we started the War of Independence.', 'It is this freedom that we must protect and nurture and build on.', "If we are not free, no one will res\nMy second vision\nfor India's development.", 'For fifty years we have been a\nIt is time we\nourselves\nas a developed\nnation.', 'We are among 
# ...
