# %% [markdown]
# ## Named Entity Recognition

# %% [markdown]
# Named Entity: Any word or group of words that refer to a specific person, place, organization, or other object or concept.
# use cases : Information Extraction , Sentiment Analysis , Recommendation Systems

# %% [markdown]
# "The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."
# Person Eg: Krish C Naik.
# Place Or Location Eg: India.
# Date Eg: September, 24-09-1989.
# Time Eg: 4:30pm
# Money Eg: 1 million dollar.
# Organization Eg: iNeuron Private Limited.
# Percent Eg: 20%, twenty percent.

# %%
import nltk 
from nltk import word_tokenize 
from nltk.chunk import ne_chunk
# chunk here means to group the words based on their named entity type 
nltk.download('words') # Download the words corpus for named entity recognition
nltk.download('maxent_ne_chunker_tab') # Download the named entity chunker 
sentence = "The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."
# Out:
# [nltk_data] Downloading package words to /Users/anantjain/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /Users/anantjain/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!

# %%
# %pip install svgling #for visualization of named entity recognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [svgling]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
words = word_tokenize(sentence)
tags_elements = nltk.pos_tag(words)
ne_chunk(tags_elements)
# Out:
# Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), ('was', 'VBD'), ('built', 'VBN'), ('from', 'IN'), ('1887', 'CD'), ('to', 'TO'), ('1889', 'CD'), ('by', 'IN'), Tree('GPE', [('French', 'JJ')]), ('engineer', 'NN'), Tree('PERSON', [('Gustave', 'NNP'), ('Eiffel', 'NNP')]), (',', ','), ('whose', 'WP$'), ('company', 'NN'), ('specialized', 'VBD'), ('in', 'IN'), ('building', 'NN'), ('metal', 'NN'), ('frameworks', 'NNS'), ('and', 'CC'), ('structures', 'NNS'), ('.', '.')])
