# %% [markdown]
# every good prompt begins with the identity for your specific ai , so that ai will work for oyu o
#
# rules
# output format

# %% [markdown]
# temperature parameter : determines the creativity of resposne .
# top_k : it will take top n words from the vocab
# top_p : and it will take only those words with more than the probabilty of top_p .
