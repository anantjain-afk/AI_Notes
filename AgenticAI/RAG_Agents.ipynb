# %% [markdown]
# RAG : retrieval augmented generation , brining in specific info and giving it to ai to generate further .
# Retrieval-Augmented Generation (RAG) is the process of optimizing the output of a large language model, so it references an authoritative knowledge base outside of its training data sources before generating a response
#
#
# important -> retrieval
# there is billions of info
# how to retrieve specific info according to user query ? -> vector embeddings .
#
# Documents are PreProcessed . split into chunk , convert into vector .
# user query comes in -> convert into vector (embedding)
# similarity search happens.
# top -k relevant chunks selected .
# sent to LLM as context .
# LLM generates final ans .
