# %% [markdown]
# Recurrent Neural Networks area class of neural networks designed to process sequential data by retaining information from previous steps. they are effective for tasks where context and order matter .
#
# Imagine reading a sentence and you try to predict the next word, you don’t rely only on the current word but also remember the words that came before. RNNs work similarly by “remembering” past information and passing the output from one step as input to the next i.e it considers all the earlier words to choose the most likely next word

# %% [markdown]
# ### Recurrent neuron

# %% [markdown]
# The fundamental processing unit in RNN is Recurrent Unit . they hold a hidden state that maintains information about previous inputs in a sequence .
#   Recurrent units can "remember" information from prior steps by feeding back their hidden state, allowing them to capture dependencies across time.

# %% [markdown]
# ![Alt text](https://media.geeksforgeeks.org/wp-content/uploads/20251215090149060237/nfa-.webp)

# %% [markdown]
# ### Difference between ANN and RNN :
#
# ANN : feedforward neural network , it consists of :
# input layer , hidden layers , output layerr
# informatino flows only forward , the network have no memory of past data .
#
# whereas RNN is a special type of neural network designed for sequential data
# key feature : it has memory .
# the output depends on the current input and previous memory .
# so RNN introduces a hidden state (memory )

# %% [markdown]
# ## Forward Propogation architechture .
# at each time step t , the RNN take current input  Xt
# and previous hidden state H(t-1) and produces new hidden state Ht and output Ot .
#
# UNROLLING RNN :
# internally RNN has a loop , but in sequence , we unroll it overtime . so
# it is a representation of a Recurrent Neural Network (RNN) over time, where the network's repeating structure is expanded into a sequence of connected layers, each corresponding to a time step
#
#
# equation : ht​=f(Wx*​xt​+Wh​*h(t−1​)+bh​)
# Wx*xt : current input contribution
# Wh*h(t-1)  : previous memory contribution
# bh : biad
# f : activation function

# %% [markdown]
# ![Alt text](https://gcdnb.pbrd.co/images/XHC2qN8VqGWq.png?o=1)

# %% [markdown]
# ## Backpropagation Through Time architechture .
# now after getting final output from the forward propagation , our main aim is to reduce the loss(Y - Yo) .
# to reduce the loss we have to update all weights : (Wi , Wh , Wo)
# Wi -> weights of input
# Wh -> weights of hidden layer
# Wo -> output layer weight
# the first update will happen with Wo as we are moving backward .

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### limitatioin :
# Basic RNN struggles with long- term memory
# due to Vanishing Gradient problem .
