# %%
# In Langgraph we implement STM using checkpointers , and threads
# it stores individual conversations using threads in a config file. 
# The checkpointer is responsible for saving the state of the conversation at regular intervals, allowing us to restore it later if needed.

# There are multiple checkpointers in langgraph 
# 1. InMemoryCheckpointer: This checkpointer stores the conversation state in memory. It is fast but not persistent, meaning that if the application is restarted, the conversation state will be lost.

# %%
### Persistance using storing in postgres 

# this will be done using docker -> postgres -> langgrpah 
# 1. create a docker.compose.yml 
# 2. write postgress as service in it and set the variablese in yml 
# 3. docker compose up -d -> this will start the postgres server in docker

# %% [markdown]
# ### Persistance using storing in postgres
#
# this will be done using docker -> postgres -> langgrpah
# 1. create a docker.compose.yml
# 2. write postgress as service in it and set the variablese in yml
# 3. docker compose up -d
